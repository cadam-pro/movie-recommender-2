# %%
from kaggle.api.kaggle_api_extended import KaggleApi

# %%
DEST_FILE = "../data"
api = KaggleApi()
api.authenticate()
api.dataset_download_files("alanvourch/tmdb-movies-daily-updates", path=DEST_FILE, unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/alanvourch/tmdb-movies-daily-updates
